# %% [markdown]
# # EDA

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib 
import matplotlib.pyplot as plt 
from pandas import Series 
from matplotlib.pylab import rcParams
# %matplotlib inline
import seaborn as sns 
from datetime import datetime

##changing matplotlib parameters
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'
plt.style.use('fivethirtyeight')
insta_names = ['exploringlondon','london','londonbeautifullife','visitlondon']
days = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']


####



from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm
from fbprophet import Prophet

# %% [markdown]
# ## Functions

# %%
def bar_time_plot(names, df_name):
    #df_name['time'] = [t.strftime('%H') for t in df_name['time']]
    for nm in names:
        fig = plt.figure(figsize=(22,12))

        my_data = df_name.loc[df_name['insta_name'] == nm]
        for i,d in enumerate(days): 
            df_day = my_data.loc[my_data['day'] == d]
            df_day = df_day.groupby(df_name['time'])['num_of_likes'].mean().reset_index()
            ax = fig.add_subplot(3,3,i+1)
            ax.bar(df_day['time'],df_day['num_of_likes'])
            ax.title.set_text(nm + " " + d)
        plt.show

# %%
def bar_plot(names, df_name):
    for nm in names:
        my_data = df_name.loc[df_name['insta_name'] == nm]
        my_data = my_data.groupby('day')['num_of_likes'].mean().reset_index()
        fig = plt.figure(figsize=(12,6))
        plt.bar(my_data['day'],my_data['num_of_likes'])
        plt.title(nm)
        for i, v in enumerate(my_data['num_of_likes']):
            v_show = round(v,2)
            plt.text(i-0.3,v,str(v_show))
        plt.show

# %%
def get_df(): 
    return df_images

# %% [markdown]
# ## Exploring Data

# %%
df = pd.read_excel('instagram_metadata.xlsx')

# %%
df.head()
# Out:
#             insta_name                                       source_image  \
# 0  londonbeautifullife  https://scontent-lht6-1.cdninstagram.com/v/t51...
# 1  londonbeautifullife  https://scontent-lht6-1.cdninstagram.com/v/t51...
# 2  londonbeautifullife  https://scontent-lhr8-1.cdninstagram.com/v/t51...
# 3  londonbeautifullife  https://scontent-lhr8-2.cdninstagram.com/v/t51...
# 4  londonbeautifullife  https://scontent-lhr8-2.cdninstagram.com/v/t51...
#
#                                              Caption  Caption_length  \
# 0  1 year ago today was the last day of full free...             549
# 1  Happy Mother's Day to all the amazing mothers ...             639
# 2  📸 - @photosbyjet - who else misses Harrods? Br...             505
# 3  📸 - @girlwiththeredbob - this photo by @girlwi...             570
# 4  When the sun takes centre stage ☀️.....Shot fr...             448
#
#    followers  num_of_likes media_type  video_views  num_of_hashtags  \
# 0     628000          1078      image            0               31
# 1     628000           870      image            0               31
# 2     628000          3032      image            0               31
# 3     628000           994      image            0               31
# 4     628000           574      image            0               31
#
#    num_of_mentions        date           time
# 0                1  2021-03-15  14:13:34.000Z
# 1                2  2021-03-14  18:42:15.000Z
# 2                3  2021-03-13  18:45:35.000Z
# 3                3  2021-03-12  15:11:30.000Z
# 4                1  2021-03-10  14:35:39.000Z

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6369 entries, 0 to 6368
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   insta_name       6369 non-null   object
#  1   source_image     6346 non-null   object
#  2   Caption          6368 non-null   object
#  3   Caption_length   6369 non-null   int64
#  4   followers        6369 non-null   int64
#  5   num_of_likes     6369 non-null   int64
#  6   media_type       6369 non-null   object
#  7   video_views      6369 non-null   int64
#  8   num_of_hashtags  6369 non-null   int64
#  9   num_of_mentions  6369 non-null   int64
#  10  date             6369 non-null   object
#  11  time             6369 non-null   object
# dtypes: int64(6), object(6)
# memory usage: 597.2+ KB

# %%
df.isnull().sum()
# Out:
# insta_name          0
# source_image       23
# Caption             1
# Caption_length      0
# followers           0
# num_of_likes        0
# media_type          0
# video_views         0
# num_of_hashtags     0
# num_of_mentions     0
# date                0
# time                0
# dtype: int64

# %% [markdown]
# There are 23 values that have source image empty, this will not be a problem as I am only looking to get the right images based on other features. On the other hand, there is an empty caption, this will be an issue as I will use caption as one of the features to classify the image. I will be deleting it.
# I need to transform the date and time, they are showing as objects.

# %% [markdown]
# ## Dealing with Empty Values

# %%
df = df.dropna(subset = ['Caption'])

# %%
df.isnull().sum()
# Out:
# insta_name          0
# source_image       23
# Caption             0
# Caption_length      0
# followers           0
# num_of_likes        0
# media_type          0
# video_views         0
# num_of_hashtags     0
# num_of_mentions     0
# date                0
# time                0
# dtype: int64

# %%
df['date']= pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6368 entries, 0 to 6368
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   insta_name       6368 non-null   object
#  1   source_image     6345 non-null   object
#  2   Caption          6368 non-null   object
#  3   Caption_length   6368 non-null   int64
#  4   followers        6368 non-null   int64
#  5   num_of_likes     6368 non-null   int64
#  6   media_type       6368 non-null   object
#  7   video_views      6368 non-null   int64
#  8   num_of_hashtags  6368 non-null   int64
#  9   num_of_mentions  6368 non-null   int64
#  10  date             6368 non-null   datetime64[ns]
#  11  time             6368 non-null   object
# dtypes: datetime64[ns](1), int64(6), object(5)
# memory usage: 646.8+ KB

# %%
df['time'] = [t [:-8] for t in df['time'] ]

# %%
df['time'] = pd.to_datetime(df['time'], format = '%H:%M').dt.time

# %%
df['time']
# Out:
# 0       14:13:00
# 1       18:42:00
# 2       18:45:00
# 3       15:11:00
# 4       14:35:00
#           ...
# 6364    11:26:00
# 6365    18:12:00
# 6366    16:57:00
# 6367    08:39:00
# 6368    17:13:00
# Name: time, Length: 6368, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6368 entries, 0 to 6368
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   insta_name       6368 non-null   object
#  1   source_image     6345 non-null   object
#  2   Caption          6368 non-null   object
#  3   Caption_length   6368 non-null   int64
#  4   followers        6368 non-null   int64
#  5   num_of_likes     6368 non-null   int64
#  6   media_type       6368 non-null   object
#  7   video_views      6368 non-null   int64
#  8   num_of_hashtags  6368 non-null   int64
#  9   num_of_mentions  6368 non-null   int64
#  10  date             6368 non-null   datetime64[ns]
#  11  time             6368 non-null   object
# dtypes: datetime64[ns](1), int64(6), object(5)
# memory usage: 646.8+ KB

# %% [markdown]
# ## Day to post

# %% [markdown]
# I will only focusing on content that are images, I will discard anything that has to do with videos. My scrapper did not get any information from videos.

# %%
df.shape
# Out:
# (6368, 12)

# %%
df_images = df.loc[df['media_type']== 'image']

# %%
df_images.shape
# Out:
# (5943, 12)

# %%
print(df.shape[0] - df_images.shape[0])
# Out:
# 425

# %% [markdown]
# There were 426 posts that were videos. My data has gone down to 5943 entries in total.

# %% [markdown]
# ## EDA posting time of day

# %% [markdown]
# I want to know what day pictures get more likes, therefore I want to be able to tell what day each date is.

# %%
df_images['day'] = [date.strftime("%A") for date in df_images['date']]
# Out:
# <ipython-input-21-036e7d56e99a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_images['day'] = [date.strftime("%A") for date in df_images['date']]

# %%
df_images.head()
# Out:
#             insta_name                                       source_image  \
# 0  londonbeautifullife  https://scontent-lht6-1.cdninstagram.com/v/t51...
# 1  londonbeautifullife  https://scontent-lht6-1.cdninstagram.com/v/t51...
# 2  londonbeautifullife  https://scontent-lhr8-1.cdninstagram.com/v/t51...
# 3  londonbeautifullife  https://scontent-lhr8-2.cdninstagram.com/v/t51...
# 4  londonbeautifullife  https://scontent-lhr8-2.cdninstagram.com/v/t51...
#
#                                              Caption  Caption_length  \
# 0  1 year ago today was the last day of full free...             549
# 1  Happy Mother's Day to all the amazing mothers ...             639
# 2  📸 - @photosbyjet - who else misses Harrods? Br...             505
# 3  📸 - @girlwiththeredbob - this photo by @girlwi...             570
# 4  When the sun takes centre stage ☀️.....Shot fr...             448
#
#    followers  num_of_likes media_type  video_views  num_of_hashtags  \
# 0     628000          1078      image            0               31
# 1     628000           870      image            0               31
# 2     628000          3032      image            0               31
# 3     628000           994      image            0               31
# 4     628000           574      image            0               31
#
#    num_of_mentions       date      time        day
# 0                1 2021-03-15  14:13:00     Monday
# 1                2 2021-03-14  18:42:00     Sunday
# 2                3 2021-03-13  18:45:00   Saturday
# 3                3 2021-03-12  15:11:00     Friday
# 4                1 2021-03-10  14:35:00  Wednesday

# %%
type(df_images['day'])
# Out:
# pandas.core.series.Series

# %%
df_images.groupby(['insta_name']).first()
# Out:
#                                                           source_image  \
# insta_name
# exploringlondon      https://scontent-lhr8-1.cdninstagram.com/v/t51...
# london               https://scontent-lht6-1.cdninstagram.com/v/t51...
# londonbeautifullife  https://scontent-lht6-1.cdninstagram.com/v/t51...
# thisislondon         https://scontent-lht6-1.cdninstagram.com/v/t51...
# visitlondon          https://scontent-lcy1-1.cdninstagram.com/v/t51...
#
#                                                                Caption  \
# insta_name
# exploringlondon      It's @comicrelief 2021! We're joining in with ...
# london               A special moment in #LondonBridge, snapped by ...
# londonbeautifullife  1 year ago today was the last day of full free...
# thisislondon         Follow @thisislondon to find out best places t...
# visitlondon          We lilac this house a lot 💜 #VisitLondon [📸 @y...
#
#                      Caption_length  followers  num_of_likes media_type  \
# insta_name
# exploringlondon                 656     828000            77      image
# london                          242   25000000         42921      image
# londonbeautifullife             549     628000          1078      image
# thisislondon                     63     269000         24151      image
# visitlondon                      57     964000         12208      image
#
#                      video_views  num_of_hashtags  num_of_mentions       date  \
# insta_name
# exploringlondon                0               28                1 2021-03-19
# london                         0               13                1 2021-03-16
# londonbeautifullife            0               31                1 2021-03-15
# thisislondon                   0                1                1 2021-01-25
# visitlondon                    0                3                1 2021-03-17
#
#                          time        day
# insta_name
# exploringlondon      12:54:00     Friday
# london               17:44:00    Tuesday
# londonbeautifullife  14:13:00     Monday
# thisislondon         19:57:00     Monday
# visitlondon          18:31:00  Wednesday

# %% [markdown]
# ### Check Average of Likes per Day

# %% [markdown]
# Check the average of likes per day of all the instagram users

# %%
df_weekdays = df_images.groupby('day')['num_of_likes'].mean().reset_index()
fig = plt.figure(figsize=(12,6))
plt.bar(df_weekdays['day'],df_weekdays['num_of_likes'])
for i, v in enumerate(df_weekdays['num_of_likes']):
    v_show = round(v,2)
    plt.text(i-0.3,v,str(v_show))
    
plt.title('Average Likes Per Day')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# For all of the accounts joined together, Saturday are obviously the preferred day to post as it amounts the most likes, followed by Sunday and Tuesday.

# %% [markdown]
# ### Average for each instagram account

# %%
bar_plot(insta_names, df_images)

# %% [markdown]
# ## Time EDA

# %% [markdown]
# Check what times are best to post on each day.

# %% [markdown]
# For the bar plots to work I need to change time from a datetime datatype to String

# %%
df_images['time'] = [t.strftime('%H') for t in df_images['time']]
# Out:
# <ipython-input-27-fd85d9a25559>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_images['time'] = [t.strftime('%H') for t in df_images['time']]

# %%
bar_time_plot(insta_names,df_images)

# %% [markdown]
# ## How Many posts per day in average

# %%
for i,nm in enumerate(insta_names): 
    my_df = df_images.loc[df_images['insta_name']==nm]
    plt.figure(figsize=(20,8))
    plt.plot(my_df['day'].value_counts())
    plt.title('Number of posts per day: ' + nm)

# %%
exploringlondon = df_images.loc[df_images['insta_name']=='exploringlondon']

# %%
exploringlondon.groupby('day').sum()
# Out:
#            Caption_length  followers  num_of_likes  video_views  \
# day
# Friday              62858   90210000        299764            0
# Monday              81264  110072000        308035            0
# Saturday            91947  120004000        366335            0
# Sunday              84417  113382000        357766            0
# Thursday            71873  102620000        271116            0
# Tuesday             61500   90204000        223048            0
# Wednesday           73788  103449000        270374            0
#
#            num_of_hashtags  num_of_mentions
# day
# Friday                1668              226
# Monday                2103              287
# Saturday              2247              263
# Sunday                2127              229
# Thursday              1958              224
# Tuesday               1629              215
# Wednesday             1739              208

# %%
fig = plt.figure(figsize=(22,12))

for i,nm in enumerate(insta_names): 
    my_df = df_images.loc[df_images['insta_name']==nm]
    ax = fig.add_subplot(3,3,i+1)
    ax.plot(my_df['day'].value_counts())
    ax.title.set_text(nm + " " + nm)

# %%
plt.figure(figsize=(20,8))
plt.plot(exploringlondon['day'].value_counts())
plt.title('Number of posts per day')
# Out:
# Text(0.5, 1.0, 'Number of posts per day')

# %%
exploringlondon = exploringlondon.groupby('day')
exploringlondon.first()
# Out:
#                 insta_name                                       source_image  \
# day
# Friday     exploringlondon  https://scontent-lhr8-1.cdninstagram.com/v/t51...
# Monday     exploringlondon  https://scontent-lhr8-1.cdninstagram.com/v/t51...
# Saturday   exploringlondon  https://scontent-lhr8-1.cdninstagram.com/v/t51...
# Sunday     exploringlondon  https://scontent-lhr8-2.cdninstagram.com/v/t51...
# Thursday   exploringlondon  https://scontent-lhr8-2.cdninstagram.com/v/t51...
# Tuesday    exploringlondon  https://scontent-lhr8-2.cdninstagram.com/v/t51...
# Wednesday  exploringlondon  https://scontent-lhr8-1.cdninstagram.com/v/t51...
#
#                                                      Caption  Caption_length  \
# day
# Friday     It's @comicrelief 2021! We're joining in with ...             656
# Monday     Happy International Women's Day! Today I wante...            1048
# Saturday   Blue skies shot beautifully by @mariandthecity...             756
# Sunday     Happy Sunday! Love this pretty floral shot by ...             568
# Thursday   Waiting for evenings like these in London agai...             645
# Tuesday    Happy Tuesday! What a beautiful day outside to...             595
# Wednesday  Fiery red skies by Richmond Riverside ❤️-Thank...             521
#
#            followers  num_of_likes media_type  video_views  num_of_hashtags  \
# day
# Friday        828000            77      image            0               28
# Monday        828000           898      image            0               19
# Saturday      828000          2022      image            0               28
# Sunday        828000          6260      image            0               26
# Thursday      828000          2955      image            0               28
# Tuesday       828000           536      image            0               19
# Wednesday     828000          1538      image            0               28
#
#            num_of_mentions       date time
# day
# Friday                   1 2021-03-19   12
# Monday                   1 2021-03-08   18
# Saturday                 1 2021-03-13   17
# Sunday                   1 2021-03-14   11
# Thursday                 3 2021-03-18   18
# Tuesday                  2 2021-03-09   14
# Wednesday                1 2021-02-17   20

# %% [markdown]
# ## Save the dataframe as a CSV

# %%
#df_images.to_csv('insta_cleaned.csv')

# %% [markdown]
# # Conclusion

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Within my data there were four different Instagram accounts, these accounts however, had the same theme. A theme: is a type of content that the Instagram account owner posts about. For example: cars, motorbikes, country. The theme I have chosen was a city : London. Getting the average, we can appreciate that the Instagram users that follow this kind of Instagram pages are more active Friday, Saturday and Sunday.

# %% [markdown]
# Looking at each Instagram account individually we can differentiate how their followers react to their posts.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Exploring London: gets more likes on Fridays, Saturday and Sundays.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Moving to London: gets more likes on Sundays, Tuesdays and Wednesdays

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Londonbeautifullife: on Fridays, Saturdays and Sundays

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Lastly, Visit London: Saturday, Thursday and Wednesdays are where the average likes are higher.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We can further Explore within the day, the time of the day with a higher average of likes, Due to the time constrain I will not be able to go through all the Instagram pages. However, Exploring London will serve as an example. We can see that posting on Monday at either 05am, 12pm or 21 gets the account more likes on average. Friday in the other hand, 13:00 and 14:.00 gets the most likes
